# %% [markdown]
# # Wine Quality Prediction

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings(action='ignore')

# %% [markdown]
# #### Load the dataset

# %%
wine=pd.read_csv("Desktop/datasets/winedataset.csv")
print("Successfully Imported")
wine.head()
# Out:
# Successfully Imported
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# ...

# %% [markdown]
# ### Data Exploration

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
wine.shape
# Out:
# (1599, 12)

# %%
wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
wine.groupby("quality").mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# ...

# %% [markdown]
# ### Data Visualization

# %%
plt.figure(figsize=(6, 4))
sns.set(style="darkgrid")
ax = sns.countplot(x="quality", data=wine, palette="Set3")
ax.set(xlabel="Wine Quality", ylabel="Count")
plt.title("Distribution of Wine Quality")

plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.set(style="darkgrid")
sns.histplot(data=wine, x='alcohol', hue='quality', bins=20, kde=True, palette="Set3", alpha=0.7)
plt.xlabel("Alcohol Content")
plt.ylabel("Count")
plt.title("Histogram of Alcohol Content by Wine Quality")
plt.legend(title="Quality", loc="upper right", labels=["Low", "Medium", "High"])
plt.show()

# %%
corr = wine.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
sns.set(style="whitegrid", palette="Set3") 
sns.countplot(data=wine, x='alcohol', ax=axes[0])
axes[0].set_xlabel("Alcohol Content")
axes[0].set_ylabel("Count")
axes[0].set_title("Count of Alcohol Content")
sns.countplot(data=wine, x='pH', ax=axes[1])
axes[1].set_xlabel("pH")
axes[1].set_ylabel("Count")
axes[1].set_title("Count of pH")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Data Preparation

# %%
wine["good_quality"]=[1 if x>=6 else 0 for x in wine["quality"]]
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
X = wine.drop(['quality','good_quality'], axis = 1)
Y = wine['good_quality']

# %% [markdown]
# ### Model Training and Evaluation

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# #### Logistic Regression

# %%
lrmodel = LogisticRegression()
lrmodel.fit(X_train, Y_train)

Y_pred = lrmodel.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
print("Accuracy Score:", accuracy)
# Out:
# Accuracy Score: 0.74375

# %% [markdown]
# #### Confusion Matrix

# %%
confusion_mat = confusion_matrix(Y_test, Y_pred)
print("Confusion Matrix:\n", confusion_mat)
# Out:
# Confusion Matrix:
#  [[104  37]
#  [ 45 134]]

# %% [markdown]
# #### Linear Regression

# %%
Lrm = LinearRegression()
Lrm.fit(X_train, Y_train)

Y_pred = Lrm.predict(X_test)
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

# %%
predictions = Lrm.predict(X_test)

# %%
data_to_plot = [Y_test, predictions]

plt.figure(figsize=(8, 6))
plt.boxplot(data_to_plot, labels=['Actual', 'Predicted'], patch_artist=True,boxprops=dict(facecolor='lightgreen', color='lightgreen'),medianprops=dict(color='red'))
plt.title('Box Plot of Actual vs. Predicted Values')
plt.ylabel('Values')
plt.show()

# %%
print("LogisticRegression()"
      "Accuracy Score:",accuracy)
print("Mean Squared Error (MSE):", mse)
print("R-squared (R2) Score:", r2)
# Out:
# LogisticRegression()Accuracy Score: 0.74375
# Mean Squared Error (MSE): 0.17625674725819146
# R-squared (R2) Score: 0.2848888260533774
